# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
train = pd.read_csv("desktop/train.csv")
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                       Name   Sex  \
# count    891.000000  891.000000  891.000000                        891   891
# unique          NaN         NaN         NaN                        891     2
# top             NaN         NaN         NaN  Panula, Mr. Ernesti Arvid  male
# freq            NaN         NaN         NaN                          1   577
# mean     446.000000    0.383838    2.308642                        NaN   NaN
# std      257.353842    0.486592    0.836071                        NaN   NaN
# min        1.000000    0.000000    1.000000                        NaN   NaN
# 25%      223.500000    0.000000    2.000000                        NaN   NaN
# 50%      446.000000    0.000000    3.000000                        NaN   NaN
# 75%      668.500000    1.000000    3.000000                        NaN   NaN
# max      891.000000    1.000000    3.000000                        NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.sample(5)
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 530          531         1       2     Quick, Miss. Phyllis May  female   2.0
# 168          169         0       1          Baumann, Mr. John D    male   NaN
# 751          752         1       3          Moor, Master. Meier    male   6.0
# 768          769         0       3          Moran, Mr. Daniel J    male   NaN
# 796          797         1       1  Leader, Dr. Alice (Farnham)  female  49.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 530      1      1     26360  26.0000   NaN        S
# 168      0      0  PC 17318  25.9250   NaN        S
# 751      0      1    392096  12.4750  E121        S
# 768      1      0    371110  24.1500   NaN        Q
# 796      0      0     17465  25.9292   D17        S

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.barplot(x="Sex", y="Survived", data=train)
plt.show()

# %%
print("Percentage of females who survived:", train["Survived"][train["Sex"] == 'female'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of females who survived: 74.2038216561

# %%
print("Percentage of males who survived:", train["Survived"][train["Sex"] == 'male'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of males who survived: 18.8908145581

# %%
sns.barplot(x="Pclass", y="Survived", data=train)
plt.show()

# %%
print("Percentage of Pclass = 1 who survived:", train["Survived"][train["Pclass"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of Pclass = 2 who survived:", train["Survived"][train["Pclass"] == 2].value_counts(normalize = True)[1]*100)

print("Percentage of Pclass = 3 who survived:", train["Survived"][train["Pclass"] == 3].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of Pclass = 1 who survived: 62.962962963
# Percentage of Pclass = 2 who survived: 47.2826086957
# Percentage of Pclass = 3 who survived: 24.2362525458

# %%
sns.barplot(x="SibSp", y="Survived", data=train)
plt.show()

# %%
print("Percentage of SibSp = 0 who survived:", train["Survived"][train["SibSp"] == 0].value_counts(normalize = True)[1]*100)

print("Percentage of SibSp = 1 who survived:", train["Survived"][train["SibSp"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of SibSp = 2 who survived:", train["Survived"][train["SibSp"] == 2].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of SibSp = 0 who survived: 34.5394736842
# Percentage of SibSp = 1 who survived: 53.5885167464
# Percentage of SibSp = 2 who survived: 46.4285714286

# %%
sns.barplot(x="Parch", y="Survived", data=train)
plt.show()

# %%
train["Age"] = train["Age"].fillna(-0.5)
test=pd.read_csv("desktop/test.csv")
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test["Age"] = test["Age"].fillna(-0.5)
bins = [-1, 0, 5, 12, 18, 24, 35, 60, np.inf]
labels = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
train['AgeGroup'] = pd.cut(train["Age"], bins, labels = labels)
test['AgeGroup'] = pd.cut(test["Age"], bins, labels = labels)
sns.barplot(x="AgeGroup", y="Survived", data=train)
plt.show()

# %%
train["CabinBool"] = (train["Cabin"].notnull().astype('int'))
train["CabinBool"] .head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: CabinBool, dtype: int32

# %%
test["CabinBool"] = (test["Cabin"].notnull().astype('int'))
test["CabinBool"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: CabinBool, dtype: int32

# %%
print("Percentage of CabinBool = 1 who survived:", train["Survived"][train["CabinBool"] == 1].value_counts(normalize = True)[1]*100)

print("Percentage of CabinBool = 0 who survived:", train["Survived"][train["CabinBool"] == 0].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of CabinBool = 1 who survived: 66.6666666667
# Percentage of CabinBool = 0 who survived: 29.9854439592

# %%
sns.barplot(x="CabinBool", y="Survived", data=train)
plt.show()

# %%
test.describe(include="all")
# Out:
#         PassengerId      Pclass                                       Name  \
# count    418.000000  418.000000                                        418
# unique          NaN         NaN                                        418
# top             NaN         NaN  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# freq            NaN         NaN                                          1
# mean    1100.500000    2.265550                                        NaN
# std      120.810458    0.841838                                        NaN
# min      892.000000    1.000000                                        NaN
# 25%      996.250000    1.000000                                        NaN
# 50%     1100.500000    3.000000                                        NaN
# 75%     1204.750000    3.000000                                        NaN
# max     1309.000000    3.000000                                        NaN
#
#          Sex         Age       SibSp       Parch    Ticket        Fare  \
# count    418  418.000000  418.000000  418.000000       418  417.000000
# unique     2         NaN         NaN         NaN       363         NaN
# top     male         NaN         NaN         NaN  PC 17608         NaN
# freq     266         NaN         NaN         NaN         5         NaN
# mean     NaN   23.941388    0.447368    0.392344       NaN   35.627188
# std      NaN   17.741080    0.896760    0.981429       NaN   55.907576
# min      NaN   -0.500000    0.000000    0.000000       NaN    0.000000
# 25%      NaN    9.000000    0.000000    0.000000       NaN    7.895800
# 50%      NaN   24.000000    0.000000    0.000000       NaN   14.454200
# 75%      NaN   35.750000    1.000000    0.000000       NaN   31.500000
# max      NaN   76.000000    8.000000    9.000000       NaN  512.329200
#
#                   Cabin Embarked     AgeGroup   CabinBool
# count                91      418          418  418.000000
# unique               76        3            8         NaN
# top     B57 B59 B63 B66        S  Young Adult         NaN
# freq                  3      270           96         NaN
# mean                NaN      NaN          NaN    0.217703
# std                 NaN      NaN          NaN    0.413179
# min                 NaN      NaN          NaN    0.000000
# 25%                 NaN      NaN          NaN    0.000000
# 50%                 NaN      NaN          NaN    0.000000
# 75%                 NaN      NaN          NaN    0.000000
# max                 NaN      NaN          NaN    1.000000

# %%
train = train.drop(['Cabin'], axis = 1)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked     AgeGroup  CabinBool
# 0      0         A/5 21171   7.2500        S      Student          0
# 1      0          PC 17599  71.2833        C        Adult          1
# 2      0  STON/O2. 3101282   7.9250        S  Young Adult          0
# 3      0            113803  53.1000        S  Young Adult          1
# 4      0            373450   8.0500        S  Young Adult          0

# %%
train = train.drop(['Ticket'], axis = 1)
test = test.drop(['Ticket'], axis = 1)
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Cabin Embarked     AgeGroup  CabinBool
# 0  34.5      0      0   7.8292   NaN        Q  Young Adult          0
# 1  47.0      1      0   7.0000   NaN        S        Adult          0
# 2  62.0      0      0   9.6875   NaN        Q       Senior          0
# 3  27.0      0      0   8.6625   NaN        S  Young Adult          0
# 4  22.0      1      1  12.2875   NaN        S      Student          0

# %%
print("Number of people embarking in Southampton (S):")
southampton = train[train["Embarked"] == "S"].shape[0]
print(southampton)

print("Number of people embarking in Cherbourg (C):")
cherbourg = train[train["Embarked"] == "C"].shape[0]
print(cherbourg)

print("Number of people embarking in Queenstown (Q):")
queenstown = train[train["Embarked"] == "Q"].shape[0]
print(queenstown)
# Out:
# Number of people embarking in Southampton (S):
# 644
# Number of people embarking in Cherbourg (C):
# 168
# Number of people embarking in Queenstown (Q):
# 77

# %%
train = train.fillna({"Embarked": "S"})
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked     AgeGroup  CabinBool
# 0      0   7.2500        S      Student          0
# 1      0  71.2833        C        Adult          1
# 2      0   7.9250        S  Young Adult          0
# 3      0  53.1000        S  Young Adult          1
# 4      0   8.0500        S  Young Adult          0

# %%
combine = [train, test]
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train['Title'], train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Capt', 'Col',
    'Don', 'Dr', 'Major', 'Rev', 'Jonkheer', 'Dona'], 'Rare')
    
    dataset['Title'] = dataset['Title'].replace(['Countess', 'Lady', 'Sir'], 'Royal')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.285714
# 5   Royal  1.000000

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Royal": 5, "Rare": 6}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(0)

train.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male  -0.5      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male  -0.5      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female  -0.5      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male  -0.5      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female  -0.5      0
# 29                                Todoroff, Mr. Lalio    male  -0.5      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  -0.5      1
# 32                           Glynn, Miss. Mary Agatha  female  -0.5      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male  -0.5      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male  -0.5      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male  -0.5      0
# 46                                  Lennon, Mr. Denis    male  -0.5      1
# 47                          O'Driscoll, Miss. Bridget  female  -0.5      0
# 48                                Samaan, Mr. Youssef    male  -0.5      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
#
#     Parch      Fare Embarked     AgeGroup  CabinBool  Title
# 0       0    7.2500        S      Student          0      1
# 1       0   71.2833        C        Adult          1      3
# 2       0    7.9250        S  Young Adult          0      2
# 3       0   53.1000        S  Young Adult          1      3
# 4       0    8.0500        S  Young Adult          0      1
# 5       0    8.4583        Q      Unknown          0      1
# 6       0   51.8625        S        Adult          1      1
# 7       1   21.0750        S         Baby          0      4
# 8       2   11.1333        S  Young Adult          0      3
# 9       0   30.0708        C     Teenager          0      3
# 10      1   16.7000        S         Baby          1      2
# 11      0   26.5500        S        Adult          1      2
# 12      0    8.0500        S      Student          0      1
# 13      5   31.2750        S        Adult          0      1
# 14      0    7.8542        S     Teenager          0      2
# 15      0   16.0000        S        Adult          0      3
# 16      1   29.1250        Q         Baby          0      4
# 17      0   13.0000        S      Unknown          0      1
# 18      0   18.0000        S  Young Adult          0      3
# 19      0    7.2250        C      Unknown          0      3
# 20      0   26.0000        S  Young Adult          0      1
# 21      0   13.0000        S  Young Adult          1      1
# 22      0    8.0292        Q     Teenager          0      2
# 23      0   35.5000        S  Young Adult          1      1
# 24      1   21.0750        S        Child          0      2
# 25      5   31.3875        S        Adult          0      3
# 26      0    7.2250        C      Unknown          0      1
# 27      2  263.0000        S      Student          1      1
# 28      0    7.8792        Q      Unknown          0      2
# 29      0    7.8958        S      Unknown          0      1
# 30      0   27.7208        C        Adult          0      6
# 31      0  146.5208        C      Unknown          1      3
# 32      0    7.7500        Q      Unknown          0      2
# 33      0   10.5000        S       Senior          0      1
# 34      0   82.1708        C  Young Adult          0      1
# 35      0   52.0000        S        Adult          0      1
# 36      0    7.2292        C      Unknown          0      1
# 37      0    8.0500        S      Student          0      1
# 38      0   18.0000        S     Teenager          0      2
# 39      0   11.2417        C     Teenager          0      2
# 40      0    9.4750        S        Adult          0      3
# 41      0   21.0000        S  Young Adult          0      3
# 42      0    7.8958        C      Unknown          0      1
# 43      2   41.5792        C         Baby          0      2
# 44      0    7.8792        Q      Student          0      2
# 45      0    8.0500        S      Unknown          0      1
# 46      0   15.5000        Q      Unknown          0      1
# 47      0    7.7500        Q      Unknown          0      2
# 48      0   21.6792        C      Unknown          0      1
# 49      0   17.8000        S     Teenager          0      3

# %%
mr_age = train[train["Title"] == 1]["AgeGroup"].mode() #Young Adult
miss_age = train[train["Title"] == 2]["AgeGroup"].mode() #Student
mrs_age = train[train["Title"] == 3]["AgeGroup"].mode() #Adult
master_age = train[train["Title"] == 4]["AgeGroup"].mode() #Baby
royal_age = train[train["Title"] == 5]["AgeGroup"].mode() #Adult
rare_age = train[train["Title"] == 6]["AgeGroup"].mode() #Adult
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male  -0.5      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male  -0.5      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female  -0.5      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male  -0.5      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female  -0.5      0
# 29                                Todoroff, Mr. Lalio    male  -0.5      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  -0.5      1
# 32                           Glynn, Miss. Mary Agatha  female  -0.5      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male  -0.5      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male  -0.5      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male  -0.5      0
# 46                                  Lennon, Mr. Denis    male  -0.5      1
# 47                          O'Driscoll, Miss. Bridget  female  -0.5      0
# 48                                Samaan, Mr. Youssef    male  -0.5      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
#
#     Parch      Fare Embarked     AgeGroup  CabinBool  Title
# 0       0    7.2500        S      Student          0      1
# 1       0   71.2833        C        Adult          1      3
# 2       0    7.9250        S  Young Adult          0      2
# 3       0   53.1000        S  Young Adult          1      3
# 4       0    8.0500        S  Young Adult          0      1
# 5       0    8.4583        Q      Unknown          0      1
# 6       0   51.8625        S        Adult          1      1
# 7       1   21.0750        S         Baby          0      4
# 8       2   11.1333        S  Young Adult          0      3
# 9       0   30.0708        C     Teenager          0      3
# 10      1   16.7000        S         Baby          1      2
# 11      0   26.5500        S        Adult          1      2
# 12      0    8.0500        S      Student          0      1
# 13      5   31.2750        S        Adult          0      1
# 14      0    7.8542        S     Teenager          0      2
# 15      0   16.0000        S        Adult          0      3
# 16      1   29.1250        Q         Baby          0      4
# 17      0   13.0000        S      Unknown          0      1
# 18      0   18.0000        S  Young Adult          0      3
# 19      0    7.2250        C      Unknown          0      3
# 20      0   26.0000        S  Young Adult          0      1
# 21      0   13.0000        S  Young Adult          1      1
# 22      0    8.0292        Q     Teenager          0      2
# 23      0   35.5000        S  Young Adult          1      1
# 24      1   21.0750        S        Child          0      2
# 25      5   31.3875        S        Adult          0      3
# 26      0    7.2250        C      Unknown          0      1
# 27      2  263.0000        S      Student          1      1
# 28      0    7.8792        Q      Unknown          0      2
# 29      0    7.8958        S      Unknown          0      1
# 30      0   27.7208        C        Adult          0      6
# 31      0  146.5208        C      Unknown          1      3
# 32      0    7.7500        Q      Unknown          0      2
# 33      0   10.5000        S       Senior          0      1
# 34      0   82.1708        C  Young Adult          0      1
# 35      0   52.0000        S        Adult          0      1
# 36      0    7.2292        C      Unknown          0      1
# 37      0    8.0500        S      Student          0      1
# 38      0   18.0000        S     Teenager          0      2
# 39      0   11.2417        C     Teenager          0      2
# 40      0    9.4750        S        Adult          0      3
# 41      0   21.0000        S  Young Adult          0      3
# 42      0    7.8958        C      Unknown          0      1
# 43      2   41.5792        C         Baby          0      2
# 44      0    7.8792        Q      Student          0      2
# 45      0    8.0500        S      Unknown          0      1
# 46      0   15.5000        Q      Unknown          0      1
# 47      0    7.7500        Q      Unknown          0      2
# 48      0   21.6792        C      Unknown          0      1
# 49      0   17.8000        S     Teenager          0      3

# %%
mr_age = train[train["Title"] == 1]["AgeGroup"].mode()
mr_age
# Out:
# 0    Young Adult
# Name: AgeGroup, dtype: category
# Categories (8, object): [Unknown < Baby < Child < Teenager < Student < Young Adult < Adult < Senior]

# %%
mr_age = train[train["Title"] == 1]["AgeGroup"].mode() #Young Adult
miss_age = train[train["Title"] == 2]["AgeGroup"].mode() #Student
mrs_age = train[train["Title"] == 3]["AgeGroup"].mode() #Adult
master_age = train[train["Title"] == 4]["AgeGroup"].mode() #Baby
royal_age = train[train["Title"] == 5]["AgeGroup"].mode() #Adult
rare_age = train[train["Title"] == 6]["AgeGroup"].mode() #Adult

age_title_mapping = {1: "Young Adult", 2: "Student", 3: "Adult", 4: "Baby", 5: "Adult", 6: "Adult"}
for x in range(len(train["AgeGroup"])):
    if train["AgeGroup"][x] == "Unknown":
        train["AgeGroup"][x] = age_title_mapping[train["Title"][x]]
        
for x in range(len(test["AgeGroup"])):
    if test["AgeGroup"][x] == "Unknown":
        test["AgeGroup"][x] = age_title_mapping[test["Title"][x]]
train.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  -0.5      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch     Fare Embarked     AgeGroup  CabinBool  Title
# 0      0   7.2500        S      Student          0      1
# 1      0  71.2833        C        Adult          1      3
# 2      0   7.9250        S  Young Adult          0      2
# 3      0  53.1000        S  Young Adult          1      3
# 4      0   8.0500        S  Young Adult          0      1
# 5      0   8.4583        Q  Young Adult          0      1
# 6      0  51.8625        S        Adult          1      1
# 7      1  21.0750        S         Baby          0      4

# %%
age_mapping = {'Baby': 1, 'Child': 2, 'Teenager': 3, 'Student': 4, 'Young Adult': 5, 'Adult': 6, 'Senior': 7}
train['AgeGroup'] = train['AgeGroup'].map(age_mapping)
test['AgeGroup'] = test['AgeGroup'].map(age_mapping)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  AgeGroup  CabinBool  Title
# 0      0   7.2500        S         4          0      1
# 1      0  71.2833        C         6          1      3
# 2      0   7.9250        S         5          0      2
# 3      0  53.1000        S         5          1      3
# 4      0   8.0500        S         5          0      1

# %%
train = train.drop(['Age'], axis = 1)
test = test.drop(['Age'], axis = 1)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#       Fare Embarked  AgeGroup  CabinBool  Title
# 0   7.2500        S         4          0      1
# 1  71.2833        C         6          1      3
# 2   7.9250        S         5          0      2
# 3  53.1000        S         5          1      3
# 4   8.0500        S         5          0      1

# %%
train = train.drop(['Name'], axis = 1)
test = test.drop(['Name'], axis = 1)
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  SibSp  Parch     Fare Embarked  \
# 0            1         0       3    male      1      0   7.2500        S
# 1            2         1       1  female      1      0  71.2833        C
# 2            3         1       3  female      0      0   7.9250        S
# 3            4         1       1  female      1      0  53.1000        S
# 4            5         0       3    male      0      0   8.0500        S
#
#    AgeGroup  CabinBool  Title
# 0         4          0      1
# 1         6          1      3
# 2         5          0      2
# 3         5          1      3
# 4         5          0      1

# %%
sex_mapping = {"male": 0, "female": 1}
train['Sex'] = train['Sex'].map(sex_mapping)
test['Sex'] = test['Sex'].map(sex_mapping)

train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare Embarked  \
# 0            1         0       3    0      1      0   7.2500        S
# 1            2         1       1    1      1      0  71.2833        C
# 2            3         1       3    1      0      0   7.9250        S
# 3            4         1       1    1      1      0  53.1000        S
# 4            5         0       3    0      0      0   8.0500        S
#
#    AgeGroup  CabinBool  Title
# 0         4          0      1
# 1         6          1      3
# 2         5          0      2
# 3         5          1      3
# 4         5          0      1

# %%
embarked_mapping = {"S": 1, "C": 2, "Q": 3}
train['Embarked'] = train['Embarked'].map(embarked_mapping)
test['Embarked'] = test['Embarked'].map(embarked_mapping)

train.head()
test.head(5)
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch     Fare Cabin  Embarked  AgeGroup  \
# 0          892       3    0      0      0   7.8292   NaN         3         5
# 1          893       3    1      1      0   7.0000   NaN         1         6
# 2          894       2    0      0      0   9.6875   NaN         3         7
# 3          895       3    0      0      0   8.6625   NaN         1         5
# 4          896       3    1      1      1  12.2875   NaN         1         4
#
#    CabinBool  Title
# 0          0      1
# 1          0      3
# 2          0      1
# 3          0      1
# 4          0      3

# %%
for x in range(len(test["Fare"])):
    if pd.isnull(test["Fare"][x]):
        pclass = test["Pclass"][x] #Pclass = 3
        test["Fare"][x] = train[train["Pclass"] == pclass]["Fare"].mean()
test.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch     Fare Cabin  Embarked  AgeGroup  \
# 0          892       3    0      0      0   7.8292   NaN         3         5
# 1          893       3    1      1      0   7.0000   NaN         1         6
# 2          894       2    0      0      0   9.6875   NaN         3         7
# 3          895       3    0      0      0   8.6625   NaN         1         5
# 4          896       3    1      1      1  12.2875   NaN         1         4
#
#    CabinBool  Title
# 0          0      1
# 1          0      3
# 2          0      1
# 3          0      1
# 4          0      3

# %%
train['FareBand'] = pd.qcut(train['Fare'], 4, labels = [1, 2, 3, 4])
test['FareBand'] = pd.qcut(test['Fare'], 4, labels = [1, 2, 3, 4])
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare  Embarked  \
# 0            1         0       3    0      1      0   7.2500         1
# 1            2         1       1    1      1      0  71.2833         2
# 2            3         1       3    1      0      0   7.9250         1
# 3            4         1       1    1      1      0  53.1000         1
# 4            5         0       3    0      0      0   8.0500         1
#
#    AgeGroup  CabinBool  Title FareBand
# 0         4          0      1        1
# 1         6          1      3        4
# 2         5          0      2        2
# 3         5          1      3        4
# 4         5          0      1        2

# %%
train = train.drop(['Fare'], axis = 1)
test = test.drop(['Fare'], axis = 1)
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  SibSp  Parch  Embarked  AgeGroup  \
# 0            1         0       3    0      1      0         1         4
# 1            2         1       1    1      1      0         2         6
# 2            3         1       3    1      0      0         1         5
# 3            4         1       1    1      1      0         1         5
# 4            5         0       3    0      0      0         1         5
#
#    CabinBool  Title FareBand
# 0          0      1        1
# 1          1      3        4
# 2          0      2        2
# 3          1      3        4
# 4          0      1        2

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch Cabin  Embarked  AgeGroup  \
# 0          892       3    0      0      0   NaN         3         5
# 1          893       3    1      1      0   NaN         1         6
# 2          894       2    0      0      0   NaN         3         7
# 3          895       3    0      0      0   NaN         1         5
# 4          896       3    1      1      1   NaN         1         4
#
#    CabinBool  Title FareBand
# 0          0      1        1
# 1          0      3        1
# 2          0      1        2
# 3          0      1        2
# 4          0      3        2

# %%
from sklearn.model_selection import train_test_split

predictors = train.drop(['Survived', 'PassengerId'], axis=1)
target = train["Survived"]
x_train, x_val, y_train, y_val = train_test_split(predictors, target, test_size = 0.22, random_state = 0)
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
y_pred = gaussian.predict(x_val)
acc_gaussian = accuracy_score(y_pred, y_val)*100
print(acc_gaussian)
# Out:
# 78.6802030457

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_val)
acc_logreg = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_logreg)
# Out:
# 79.19

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_val)
acc_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_svc)
# Out:
# 82.74

# %%
from sklearn.svm import LinearSVC

linear_svc = LinearSVC()
linear_svc.fit(x_train, y_train)
y_pred = linear_svc.predict(x_val)
acc_linear_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_linear_svc)
# Out:
# 78.17

# %%
from sklearn.linear_model import Perceptron

perceptron = Perceptron()
perceptron.fit(x_train, y_train)
y_pred = perceptron.predict(x_val)
acc_perceptron = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_perceptron)
# Out:
# 79.19

# %%
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()
decisiontree.fit(x_train, y_train)
y_pred = decisiontree.predict(x_val)
acc_decisiontree = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_decisiontree)
# Out:
# 79.7

# %%
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier()
randomforest.fit(x_train, y_train)
y_pred = randomforest.predict(x_val)
acc_randomforest = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_randomforest)
# Out:
# 84.26

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_val)
acc_knn = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_knn)
# Out:
# 77.66

# %%
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.fit(x_train, y_train)
y_pred = sgd.predict(x_val)
acc_sgd = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_sgd)
# Out:
# 76.65

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbk = GradientBoostingClassifier()
gbk.fit(x_train, y_train)
y_pred = gbk.predict(x_val)
acc_gbk = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gbk)
# Out:
# 84.77

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 'Linear SVC', 
              'Decision Tree', 'Stochastic Gradient Descent', 'Gradient Boosting Classifier'],
    'Score': [acc_svc, acc_knn, acc_logreg, 
              acc_randomforest, acc_gaussian, acc_perceptron,acc_linear_svc, acc_decisiontree,
              acc_sgd, acc_gbk]})
models.sort_values(by='Score', ascending=False)
# Out:
#                           Model      Score
# 9  Gradient Boosting Classifier  84.770000
# 3                 Random Forest  84.260000
# 0       Support Vector Machines  82.740000
# 7                 Decision Tree  79.700000
# 2           Logistic Regression  79.190000
# 5                    Perceptron  79.190000
# 4                   Naive Bayes  78.680203
# 6                    Linear SVC  78.170000
# 1                           KNN  77.660000
# 8   Stochastic Gradient Descent  76.650000

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch Cabin  Embarked  AgeGroup  \
# 0          892       3    0      0      0   NaN         3         5
# 1          893       3    1      1      0   NaN         1         6
# 2          894       2    0      0      0   NaN         3         7
# 3          895       3    0      0      0   NaN         1         5
# 4          896       3    1      1      1   NaN         1         4
#
#    CabinBool  Title FareBand
# 0          0      1        1
# 1          0      3        1
# 2          0      1        2
# 3          0      1        2
# 4          0      3        2

# %%
test=test.drop('Cabin',axis=1)
test.head()
# Out:
#    PassengerId  Pclass  Sex  SibSp  Parch  Embarked  AgeGroup  CabinBool  \
# 0          892       3    0      0      0         3         5          0
# 1          893       3    1      1      0         1         6          0
# 2          894       2    0      0      0         3         7          0
# 3          895       3    0      0      0         1         5          0
# 4          896       3    1      1      1         1         4          0
#
#    Title FareBand
# 0      1        1
# 1      3        1
# 2      1        2
# 3      1        2
# 4      3        2

# %%
ids = test['PassengerId']
ids.head()
# Out:
# 0    892
# 1    893
# 2    894
# 3    895
# 4    896
# Name: PassengerId, dtype: int64

# %%
test=test.drop('PassengerId' ,axis=1)
test.head()
# Out:
#    Pclass  Sex  SibSp  Parch  Embarked  AgeGroup  CabinBool  Title FareBand
# 0       3    0      0      0         3         5          0      1        1
# 1       3    1      1      0         1         6          0      3        1
# 2       2    0      0      0         3         7          0      1        2
# 3       3    0      0      0         1         5          0      1        2
# 4       3    1      1      1         1         4          0      3        2

# %%
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier()
randomforest.fit(x_train, y_train)
predict=randomforest.predict(test)
output = pd.DataFrame({ 'PassengerId' : ids, 'Survived': predict })
output
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         1
# 18           910         0
# 19           911         1
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         1
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         0
# 391         1283         1
# 392         1284         1
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         1
# 405         1297         1
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         0
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
output.to_csv('submission.csv', index=False)
